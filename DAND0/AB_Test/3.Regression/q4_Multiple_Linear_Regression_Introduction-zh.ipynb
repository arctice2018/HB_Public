# %% [markdown]
# ### 多元线性回归简介
#
# 在 notebook 以及下面的测试题目中，你将创建几个简单的线性回归模型以及多元线性回归模型来预测房屋价值。
#
# 首先，让我们导入必要的库并读取你将使用的数据，然后开始你的任务吧。

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sms;

df = pd.read_csv('house_prices.csv')
df.head()
# Out:
#    house_id neighborhood  area  bedrooms  bathrooms      style    price
# 0      1112            B  1188         3          2      ranch   598291
# 1       491            B  3512         5          3  victorian  1744259
# 2      5952            B  1134         3          2      ranch   571669
# 3      3525            A  1940         4          2      ranch   493675
# 4      5108            B  2208         6          4  victorian  1101539

# %% [markdown]
# 1. 使用 statsmodels，拟合三个单独的简单线性回归模型来预测价格。 在这三个模型中，应有一个使用 **area** ，一个使用 **bedrooms** ，另一个使用 **bathrooms** 。另外，每个模型中都要使用一个截距。 使用每个模型的结果来回答下面的前两个测试题目。

# %%
df['intercept'] = 1
lr_area = sms.OLS(df['price'],df['area'])
result = lr_area.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.895
# Model:                            OLS   Adj. R-squared:                  0.895
# Method:                 Least Squares   F-statistic:                 5.152e+04
# Date:                Sat, 29 Feb 2020   Prob (F-statistic):               0.00
# Time:                        21:29:06   Log-Likelihood:                -84518.
# No. Observations:                6028   AIC:                         1.690e+05
# Df Residuals:                    6027   BIC:                         1.690e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# area         351.8265      1.550    226.980      0.000     348.788     354.865
# ==============================================================================
# Omnibus:                      361.722   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              315.288
# Skew:                           0.490   Prob(JB):                     3.44e-69
# Kurtosis:                       2.458   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lr_bed = sms.OLS(df['price'],df['bedrooms'])
result = lr_bed.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.853
# Model:                            OLS   Adj. R-squared:                  0.853
# Method:                 Least Squares   F-statistic:                 3.488e+04
# Date:                Sat, 29 Feb 2020   Prob (F-statistic):               0.00
# Time:                        21:30:05   Log-Likelihood:                -85547.
# No. Observations:                6028   AIC:                         1.711e+05
# Df Residuals:                    6027   BIC:                         1.711e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# bedrooms    2.073e+05   1110.004    186.759      0.000    2.05e+05    2.09e+05
# ==============================================================================
# Omnibus:                     1275.663   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2509.103
# Skew:                           1.276   Prob(JB):                         0.00
# Kurtosis:                       4.866   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lr_bath = sms.OLS(df['price'],df['bathrooms'])
result = lr_bath.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.850
# Model:                            OLS   Adj. R-squared:                  0.850
# Method:                 Least Squares   F-statistic:                 3.425e+04
# Date:                Sat, 29 Feb 2020   Prob (F-statistic):               0.00
# Time:                        21:31:25   Log-Likelihood:                -85593.
# No. Observations:                6028   AIC:                         1.712e+05
# Df Residuals:                    6027   BIC:                         1.712e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# bathrooms   3.449e+05   1863.685    185.071      0.000    3.41e+05    3.49e+05
# ==============================================================================
# Omnibus:                      746.297   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1138.986
# Skew:                           0.894   Prob(JB):                    4.70e-248
# Kurtosis:                       4.158   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# 2. 你已经看到了简单线性回归模型的结果，接下来，让我们同时使用这三个变量尝试一个多元线性回归模型。在这个模型中，做一个截距。

# %%
df.head()
# Out:
#    house_id neighborhood  area  bedrooms  bathrooms      style    price  \
# 0      1112            B  1188         3          2      ranch   598291
# 1       491            B  3512         5          3  victorian  1744259
# 2      5952            B  1134         3          2      ranch   571669
# 3      3525            A  1940         4          2      ranch   493675
# 4      5108            B  2208         6          4  victorian  1101539
#
#    intercept
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %%
mlr = sms.OLS(df['price'],df[['area','bedrooms','bathrooms']])
result = mlr.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.895
# Model:                            OLS   Adj. R-squared:                  0.895
# Method:                 Least Squares   F-statistic:                 1.717e+04
# Date:                Sat, 29 Feb 2020   Prob (F-statistic):               0.00
# Time:                        21:32:55   Log-Likelihood:                -84517.
# No. Observations:                6028   AIC:                         1.690e+05
# Df Residuals:                    6025   BIC:                         1.691e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# area         344.9076      7.153     48.218      0.000     330.885     358.930
# bedrooms    3333.9846   7981.383      0.418      0.676   -1.23e+04     1.9e+04
# bathrooms   1586.0714    1.3e+04      0.122      0.903   -2.39e+04     2.7e+04
# ==============================================================================
# Omnibus:                      362.518   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              331.730
# Skew:                           0.513   Prob(JB):                     9.24e-73
# Kurtosis:                       2.482   Cond. No.                     9.54e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.54e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# 3. 除了使用 **area** 、 **bedrooms** 与 **bathrooms** ，你可能还想使用 **style** 来预测房屋价格。尝试把它添加到你的多元线性回归模型中吧。你得到了什么结果？通过下面的最后一道测试题目给出你的答案吧。

# %%
mlr = sms.OLS(df['price'],df[['area','bedrooms','bathrooms','style']])
result = mlr.fit()
result.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-70609a2ccf49> in <module>()
# ----> 1 mlr = sms.OLS(df['price'],df[['area','bedrooms','bathrooms','style']])
#       2 result = mlr.fit()
#       3 result.summary()
#
# ~\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     815                  **kwargs):
#     816         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 817                                   hasconst=hasconst, **kwargs)
#     818         if "weights" in self._init_keys:
#     819             self._init_keys.remove("weights")
#
# ~\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     661             weights = weights.squeeze()
#     662         super(WLS, self).__init__(endog, exog, missing=missing,
# --> 663                                   weights=weights, hasconst=hasconst, **kwargs)
#     664         nobs = self.exog.shape[0]
#     665         weights = self.weights
#
# ~\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, **kwargs)
#     177     """
#     178     def __init__(self, endog, exog, **kwargs):
# --> 179         super(RegressionModel, self).__init__(endog, exog, **kwargs)
#     180         self._data_attr.extend(['pinv_wexog', 'wendog', 'wexog', 'weights'])
#     181
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#     210
#     211     def __init__(self, endog, exog=None, **kwargs):
# --> 212         super(LikelihoodModel, self).__init__(endog, exog, **kwargs)
#     213         self.initialize()
#     214
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#      62         hasconst = kwargs.pop('hasconst', None)
#      63         self.data = self._handle_data(endog, exog, missing, hasconst,
# ---> 64                                       **kwargs)
#      65         self.k_constant = self.data.k_constant
#      66         self.exog = self.data.exog
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\model.py in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#      85
#      86     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# ---> 87         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#      88         # kwargs arrays could have changed, easier to just attach here
#      89         for key in kwargs:
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\data.py in handle_data(endog, exog, missing, hasconst, **kwargs)
#     631     klass = handle_data_class_factory(endog, exog)
#     632     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
# --> 633                  **kwargs)
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\data.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      74             self.orig_endog = endog
#      75             self.orig_exog = exog
# ---> 76             self.endog, self.exog = self._convert_endog_exog(endog, exog)
#      77
#      78         # this has side-effects, attaches k_constant and const_idx
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\data.py in _convert_endog_exog(self, endog, exog)
#     472         exog = exog if exog is None else np.asarray(exog)
#     473         if endog.dtype == object or exog is not None and exog.dtype == object:
# --> 474             raise ValueError("Pandas data cast to numpy dtype of object. "
#     475                              "Check input data with np.asarray(data).")
#     476         return super(PandasData, self)._convert_endog_exog(endog, exog)
#
# ValueError: Pandas data cast to numpy dtype of object. Check input data with np.asarray(data).
