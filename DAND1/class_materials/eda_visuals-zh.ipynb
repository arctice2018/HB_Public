# %% [markdown]
# # 用可视化工具进行探索性数据分析
# 创建可视化图表，回答该 notebook 下方的测试题。

# %%
# 加载数据集

import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv("winequality_edited.csv",sep=",")

# %% [markdown]
# ### 各个特征的直方图

# %%
df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   red
# 1      9.8        5   red
# 2      9.8        5   red
# 3      9.8        6   red
# 4      9.4        5   red

# %%
df.hist(figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f95a7a9f198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f95a7a72240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f95a7a2f780>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f95a79e7780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f95a7a0d588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f95a7a0d5f8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f95a7981e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f95a793bda0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f95a78f8da0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f95a78ab5c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f95a78625c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f95a789ba90>]], dtype=object)

# %% [markdown]
# ### 质量与各个特征的散点图

# %%
df.columns
type(df.columns)
type(list(df.columns))
# Out:
# list

# %%
for c in df.columns[:-2]:
    df.plot.scatter(x=c,y="quality")
